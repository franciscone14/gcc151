# %%
import nltk
# nltk.download()

# %% [markdown]
# # Interesting reading:
# https://www.nltk.org/book/ch08.html

# %% [markdown]
# # Ambiguity

# %%
# PP -> Indica a circunstancia (Sintagma), refere-se ao NP

simple_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'eu'
VP -> V NP | VP PP
Det -> 'um' | 'meus'
N -> 'elefante' | 'pijamas' | 'cachorro'
V -> 'mordi'
P -> 'em' | 'com' | 'para'
""")

# %%
# Para resolver a ambiguidade sem olhar a semantica podemos olhar a frequencia de meus pijamas se refere
sentence = 'Eu mordi um cachorro com meus pijamas'.lower().split()
parser = nltk.ChartParser(simple_grammar)
trees = parser.parse(sentence)
for tree in trees:
    print(tree)
# Out:
# (S
#   (NP eu)
#   (VP
#     (VP (V mordi) (NP (Det um) (N cachorro)))
#     (PP (P com) (NP (Det meus) (N pijamas)))))
# (S
#   (NP eu)
#   (VP
#     (V mordi)
#     (NP
#       (Det um)
#       (N cachorro)
#       (PP (P com) (NP (Det meus) (N pijamas))))))

# %%
from nltk.corpus import floresta

# %%
floresta.parsed_sents()[3].draw()

# %%
productions = {}
for ps in floresta.parsed_sents():
    for prod in ps.productions():
        if prod.lhs() in productions:
            productions[prod.lhs()].add(prod.rhs())
        else:
            productions[prod.lhs()] = set()
            productions[prod.lhs()].add(prod.rhs())
# Out:
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.
# Bad tree detected; trying to recover...
#   Recovered by returning a flat parse.

# %%
CFG = []
for L, R in productions.items():
    for tup in R:
        Rs = []
        for item in tup:
            parts = []
            if not isinstance(item, nltk.grammar.Nonterminal):
                parts.append("'{}'".format(str(item)))
            else:
                parts.append(str(item))
        Rs.append(" ".join(parts))
    line = "{} -> {}".format(L, " | ".join(Rs))
    CFG.append(line.replace("+", "_").replace(">", "_>").replace("<", "_<"))

# %%
CFG
# Out:
# ['P_<_np -_> N_<PRED_fcl',
#  'P_<_? -_> ?_pp',
#  'STA_ap -_> !',
#  'CJT_np -_> N_<_pp',
#  '-ACC_fcl- -_> ADVL_fcl-',
#  'CJT_fcl -_> ADVL_pp',
#  'A_<_ap -_> A_<_pp',
#  'N_<_advp -_> A_<_pp',
#  "» -_> '»'",
#  '-P_<_np -_> N_<PRED_ap',
#  "N_<PRED_pron-indp -_> 'tudo'",
#  '-ACC_icl -_> ADVL_pp',
#  "P_<_adj -_> 'surdos'",
#  "SC_pron-indp -_> 'que'",
#  'AUX_cu -_> CJT_v-fin',
#  "ADVL_in -_> 'Rarará'",
#  'PRED_cu- -_> CJT_icl',
#  "CJT_ec -_> 'pós'",
#  "ADVL_pp -_> 'a_bordo'",
#  'QUE_acl -_> ?',
#  'ADVS_np -_> H_n',
#  'CJT_fcl- -_> ?_cu-',
#  'CJT&PASS_pp -_> P_<_np',
#  'N_</N_<[-2]_ap -_> A_<_pp',
#  'H_ap -_> NUM_<_pp',
#  'A_<_np -_> N_<_fcl',
#  "PMV_v-inf -_> 'andar'",
#  'N_</N_<[_2]_ap -_> A_<_pp',
#  'OC_np -_> H_n',
#  "FOC_conj-c -_> 'mas'",
#  "N_<_conj-c -_> 'e'",
#  "_>N_prp -_> 'Cerca_de'",
#  'S_<_np -_> N_<_fcl',
#  'ADVL/ADVL[-3]_pp -_> P_<_np',
#  '_>P_advp -_> H_adv',
#  'SUBJ_icl -_> ADVL_pp',
#  "; -_> ';'",
#  "CJT_num -_> '1994'",
#  'SC_pp- -_> P_<_ap-',
#  'H_cu -_> CJT_np',
#  'PIV_? -_> ?_pp',
#  'PMV_vp -_> MV_v-pcp',
#  'ACC_icl- -_> SC_pp',
#  "P_pron-indp -_> 'quem'",
#  '-P_<_np- -_> N_<PRED_fcl',
#  '-_>A_ap -_> KOMP_<_acl',
#  'CJT_advp -_> A_<_acl',
#  'ACC_icl -_> ADVL_pp',
#  'N_<_cu -_> CJT_adj',
#  'EXC_? -_> !',
#  "N_<[-4]_adj -_> 'nazi'",
#  'N_</N_<[_2]_icl -_> PIV_pp',
#  "QUE_v-fin -_> 'Acreditam'",
#  'A_<_cu -_> CJT_pp',
#  "N_<{'185/60_R_14'} -_> '185/60_R_14'",
#  '-_>A_pp -_> -P_<_np',
#  "PAUX_v-fin -_> 'Podemos'",
#  'H_np -_> N_<_num',
#  'QUE_icl -_> ?',
#  'P_<_ap- -_> ,',
#  '-SUBJ_cu -_> CJT_np',
#  'TOP_np -_> N_<_pron-det',
#  'PCJT_ap -_> H_num',
#  "ADVL_prp -_> 'para'",
#  "SC_v-ger -_> 'fraquejando'",
#  "QUE_adv -_> 'Como'",
#  'N_</ADVL[-2]_pp -_> P_<_np',
#  'ACC_acl -_> SUBJ_np',
#  'KOMP_<_ap -_> H_adj',
#  "H_adv -_> 'a_bordo'",
#  'ADVL_cu- -_> CJT_np',
#  'P_<_vp -_> MV_v-pcp',
#  'N_</ADVL[-1]_pp -_> P_<_num',
#  'ADVL_fcl -_> !',
#  "ACC_pron-indp -_> 'que'",
#  "QUE_n -_> 'Jazz_rap'",
#  'QUE_pp -_> ?',
#  ', -_> N_<PRED_pp',
#  "ACC-PASS_pron-pers -_> 'se'",
#  'EXC_np -_> !',
#  "ACC_>-PASS_pron-pers -_> 'se'",
#  'AS_<_fcl -_> ACC_np',
#  "PRED_v-pcp -_> 'deitado'",
#  '-CJT_cu -_> -P_<_icl',
#  'A_<_pp- -_> P_<_np-',
#  "N_<_pron-indp -_> 'tudo'",
#  "MV_v-pcp -_> 'apreciada'",
#  "H_num_263-4700' -_> '{011}_263-4700'",
#  'FOC_advp -_> H_adv',
#  '-CJT_icl -_> -ACC_icl',
#  '-P_<_fcl -_> ADVL_pp',
#  "N_<_pp -_> 'em_casa'",
#  '_>P_ap- -_> H_pron-det',
#  "SUBJ_pron-indp -_> 'Todo_mundo'",
#  'ADVL/OC_pp -_> P_<_adj',
#  "_>A_pron-det -_> 'os'",
#  'ADVL/ADVL[-1]_pp -_> P_<_icl',
#  "A_<_num -_> 'cento_e_quatro'",
#  ". -_> '.'",
#  'H_icl -_> ADVL_fcl',
#  '_>A_ap -_> H_num',
#  'VOK_np -_> N_<_prop',
#  "_>A_num -_> '50'",
#  'N_<_acl -_> SC_np',
#  "OC_v-pcp -_> 'danificada'",
#  '-N_<_pp -_> -P_<_np',
#  'PIV_icl -_> ACC_icl',
#  'PRED_ap -_> KOMP_<_acl',
#  "ADVL_v-inf -_> 'exigir'",
#  "N_</N_<[_2]_adv -_> 'anteontem'",
#  '_>A_np -_> H_n',
#  '-OC_np -_> N_<_adj',
#  '-N_<_icl -_> ADVL_pp',
#  "PIV_pron-indp -_> 'que'",
#  "ACC_num -_> 'dois'",
#  '-_>P_ap -_> KOMP_<_acl',
#  'SUBJ_pp -_> P_<_cu',
#  "SC_adv -_> 'Como'",
#  '-SC_advp -_> A_<_icl',
#  "PRT-AUX_>_prp -_> 'A'",
#  '_>A_? -_> ?_pp',
#  '-N_<PRED_fcl -_> -ADVL_pp',
#  "UTT_adj -_> 'Constrangedor'",
#  'SUBJ_fcl -_> ADVL_icl',
#  "_>A_pron-indp -_> 'nada'",
#  "N_<PRED_num -_> '73'",
#  "N_<_adj -_> 'irrecusáveis'",
#  'UTT_sq -_> STA_fcl',
#  "P_<_prp -_> 'trás'",
#  '-PAUX_vp -_> ?_cu',
#  'ACC_np- -_> H_n',
#  'PIV_fcl -_> SC_np',
#  'QUE_cu -_> ?',
#  "N_<PRED_adv -_> '20h45'",
#  "P_<_n -_> 'hipocrisia'",
#  'OC_ap -_> A_<_pp',
#  'A_<_advp -_> A_<_pp',
#  "N_<_n -_> 'sociedade'",
#  "SUBJ_n -_> 'Governador'",
#  'CJT_acl -_> ADVL_adv',
#  'APP_advp -_> A_<_pp',
#  'EXC_pp -_> !',
#  'SC_ap -_> »',
#  "CJT_v-fin -_> 'recolhem'",
#  'CJT_ap -_> H_adj',
#  '-ACC_np -_> -N_<PRED_fcl',
#  '-PMV_vp -_> »',
#  "_>N_adv -_> 'nomeadamente'",
#  'N_<PRED_acl -_> SC_np',
#  'APP_ap -_> A_<_pp',
#  '-SUBJ_fcl -_> -SUBJ_np',
#  'PAUX_vp -_> PRT-AUX_<_prp',
#  'P_<_fcl- -_> ADVL_adv',
#  "PRT-AUX_<_conj-s -_> 'que'",
#  "_>N_v-pcp -_> 'variados'",
#  '-P_<_cu -_> N_<PRED_np',
#  'PAUX_vp- -_> AUX_v-inf',
#  'ADVL_? -_> ?_pp',
#  "P_v-fin -_> 'prove'",
#  'PASS_pp -_> »',
#  'ADVL_vp -_> MV_v-pcp',
#  "SC_v-pcp -_> 'instalado'",
#  "SUBJ_adv -_> 'Hoje_de_manhã'",
#  "SUB_pron-indp -_> 'que'",
#  "OC_n -_> 'referência'",
#  '-?_cu -_> CJT_pp',
#  'AS_<_cu -_> CJT_prop',
#  '-ADVL_np -_> N_<PRED_advp',
#  'N_<_fcl- -_> ADVL_pp',
#  "/ -_> '/'",
#  "ADVL_v-ger -_> 'jogando'",
#  "N_<PRED_pron-det -_> 'todos'",
#  "H_pp -_> 'a_bordo'",
#  'SUBJ_fcl- -_> ADVL_pp',
#  '-ADVL_icl -_> P_v-inf',
#  'SC_cu- -_> CO_conj-c',
#  "ADVL_conj-s -_> 'pois'",
#  '-P_<_ap -_> H_num',
#  'ADVL/N_<[-2]_pp -_> P_<_np',
#  "P_<_num -_> 'nove'",
#  'SC_advp- -_> H_adv',
#  "OC_prop -_> 'Um_cão_,_talvez'",
#  '_>P_pp -_> P_<_adj',
#  'ADVL_icl -_> SUBJ_np',
#  '-STA_fcl -_> ACC_icl',
#  "ADVL_n -_> 'forte'",
#  "P_<_pron-pers -_> 'você'",
#  'OC_cu -_> ,',
#  '-P_<_icl- -_> ADVL_pp',
#  'PIV/N_<[_1]_pp -_> P_<_np',
#  '_>N_np -_> N_<_icl',
#  'H_np- -_> N_<_pp-',
#  'OC_np- -_> N_<_pp',
#  "N_<_prop -_> 'Sequeira_Costa'",
#  "_>P_adv -_> 'nomeadamente'",
#  'SC_fcl -_> ADVS_adv',
#  "VOK_prop -_> 'Simão'",
#  'APP_fcl -_> SUBJ_np',
#  "A_<_pron-det -_> 'mesma'",
#  'ADVL/N_<[_2]_advp -_> A_<_pp',
#  'N_<_np- -_> _>N_ap-',
#  'P_vp- -_> AUX_v-inf',
#  "-H_prp -_> 'em'",
#  "MV_v-inf -_> 'bater'",
#  "COM_conj-s -_> 'do_que'",
#  "AS_<_n -_> 'lenitivo'",
#  "N_<_num_253-1588' -_> '{011}_253-1588'",
#  'CJT_icl- -_> ADVL_advp-',
#  'H_fcl -_> ADVS_fcl',
#  "_>N_pp -_> 'por_outro_lado'",
#  '-SC_icl -_> ADVL_pp',
#  '_>P_advp- -_> H_adv',
#  'QUE_np -_> ?',
#  "ACC_v-fin -_> 'responda'",
#  '-N_<_np -_> -P_<_np',
#  "P_<_prop -_> 'Macedo'",
#  "AS_<_pron-det -_> 'esta'",
#  '-SUBJ_icl -_> ADVL_pp',
#  'P_<_np- -_> H_n',
#  "ACC_pron-pers -_> 'você'",
#  '?_icl -_> ACC_np',
#  '?_pp -_> P_<_n',
#  'KOMP_<_acl -_> SUBJ_pp',
#  "PMV_v-pcp -_> 'revistado'",
#  "CJT&PRED_adj -_> 'Simpático'",
#  '-_>N_ap -_> KOMP_<_pp',
#  'N_<PRED_cu- -_> CJT_fcl',
#  'P_cu -_> CJT_icl',
#  'CMD_icl -_> ADVL_np',
#  'ADVO_cu -_> PCJT_pp',
#  'UTT_advp -_> .',
#  'PIV_cu- -_> CJT_pp',
#  '». -_> CJT_pp',
#  "_>P_pron-det -_> 'mais'",
#  'CJT&ADVL_pp -_> P_<_np',
#  '_>N_advp -_> KOMP_<_acl',
#  'SUBJ_np- -_> N_<PRED_cu',
#  "CO_prp -_> '$/'",
#  'PASS_np -_> N_<PRED_pp',
#  "H_prp -_> 'longe_de'",
#  "N_<_prp -_> 'por'",
#  'STA_acl -_> P_v-pcp',
#  '-SUBJ_pp -_> N_<_pp',
#  'AUX_<_? -_> ADVL_pp',
#  'PIV_np -_> N_<PRED_acl',
#  'CO_advp -_> H_adv',
#  'CJT&PRED_np -_> }',
#  'SC/ADVS_pp -_> P_<_np',
#  "SUBJ_v-pcp -_> 'adequado'",
#  'N_<_ap -_> KOMP_<_fcl',
#  'ADVL/ADVL[-6]_pp -_> P_<_np',
#  "EXC_in -_> 'Socorro'",
#  "PRD_adv -_> 'Como'",
#  "APP_adj -_> 'paupérrimo'",
#  "CO_v-pcp -_> 'aceite'",
#  "ADVL_v-fin -_> 'possuem'",
#  'UTT_vp -_> .',
#  'QUE_fcl -_> ?',
#  "AUX_v-fin -_> 'tivéssemos'",
#  'S_<_fcl -_> ADVL_pp',
#  'PIV_pp -_> P_<_np',
#  'STA_fcl- -_> ACC_np',
#  "_>N_art -_> 'As'",
#  '?_np -_> H_n',
#  'H_icl- -_> ADVL_pp',
#  'PCJT_cu -_> P_<_prop',
#  '"« -_> P_<_prop',
#  "CJT_prop -_> 'Londres'",
#  'N_</P_<[_1]_pp -_> P_<_np',
#  "S -_> '('.', '.')'",
#  'P_<_icl- -_> ADVL_icl',
#  "_>A_v-pcp -_> 'demasiado'",
#  'CJT_np- -_> H_n',
#  'ACC_ap -_> KOMP_<_acl',
#  "PRT-AUX_<_pp -_> 'a'",
#  '-CJT_np -_> -P_<_np',
#  'N_<PRED_? -_> ?_pp',
#  'ADVL_cu -_> CJT_fcl',
#  '_>N_ap -_> _>N_adj',
#  'PRED_acl -_> SC_pp',
#  "H_pron-indp -_> 'Algo'",
#  "VOK_pron-pers -_> 'você'",
#  'N_<_fcl -_> ADVL_pp',
#  'APP_icl -_> ADVO_pp',
#  '-ADVL_fcl -_> SC_adj',
#  "VOC_prop -_> 'De_Gaulle'",
#  "CJT_n -_> 'acompanhamento'",
#  '-ADVL_cu -_> CJT_pp',
#  'ADVL_np -_> N_<_num',
#  'N_<PRED/N_<PRED[-3]_ap -_> A_<_pp',
#  "AUX_v-inf -_> 'ter'",
#  "CO_adv -_> 'como'",
#  "_>A_adv -_> 'geneticamente'",
#  '-_>A_advp -_> KOMP_<_fcl',
#  'CMD_fcl -_> !',
#  "H_art -_> 'O'",
#  "_>N_num -_> '108,7'",
#  'PASS_pp- -_> P_<_np-',
#  '-PASS_pp -_> -P_np',
#  "_>N_pron-pers -_> 'a'",
#  "P_<_adv -_> 'cá'",
#  '-N_<_cu -_> CJT_fcl',
#  "H_in -_> 'Não'",
#  "H_prp- -_> 'em'",
#  "ADVL_pron-det -_> 'Quanto'",
#  "SUBJ_v-inf -_> 'operar'",
#  "FOC_adv -_> 'que'",
#  'N_</ADVL[-3]_np -_> H_n',
#  'ADVL/N_<[_1]_cu -_> CJT_acl',
#  "_>A_prp -_> 'por'",
#  'UTT_? -_> ;',
#  '-CJT_pp -_> -P_<_icl',
#  "AS_<_pron-indp -_> 'isso'",
#  'ACC_np -_> N_<PRED_np',
#  "FOC_pron-indp -_> 'que'",
#  'ADVS_fcl -_> -ACC_icl',
#  'PIV_cu -_> -CJT_cu',
#  'N_<PRED_ap -_> A_<_pp',
#  'SC_fcl- -_> PRD_adv',
#  'OC_fcl -_> P_v-fin',
#  "STA_v-fin -_> 'Concluiu'",
#  'SC_np -_> N_<_fcl',
#  'PRED_np -_> N_<_pp',
#  'APP_cu- -_> ,',
#  'KOMP_<_fcl -_> P_v-fin',
#  "PMV_v-ger -_> 'enchendo'",
#  'UTT_acl -_> --',
#  'SUBJ_cu -_> CJT_np',
#  'UTT_fcl -_> .',
#  'N_<PRED/N_<PRED[_2]_pp -_> P_<_prop',
#  '_>A_pp- -_> P_<_np-',
#  "SUBJ_prop -_> 'Cravinho'",
#  '-SUBJ_np -_> N_<PRED_ap',
#  'ADVL/ADVL[_1]_fcl -_> ACC_np',
#  'EXC_acl -_> !',
#  "AS_<_prop -_> 'Sonia_Motta'",
#  "N_<_adv -_> 'por_pessoa'",
#  '_>N_pp- -_> P_<_np',
#  "PRT-AUX_prp -_> 'por'",
#  "DAT_pron-pers -_> 'me-'",
#  'N_<PRED/N_<PRED[_3]_fcl -_> PIV_pp',
#  '-A_<_pp -_> -P_<_np',
#  '_>A_cu -_> PCJT_pp',
#  "MV_v-ger -_> 'respondendo'",
#  'H_vp -_> MV_v-pcp',
#  'ACC_advp -_> H_adv',
#  'N_<_cu- -_> CJT_pp',
#  'ADVL_fcl- -_> SUB_conj-s',
#  "SC_adj -_> 'interessante'",
#  '-P_np -_> N_<PRED_fcl',
#  'N_</ADVL[-4]_pp -_> P_<_np',
#  'CJT_? -_> ADVL_fcl',
#  'UTT_icl -_> ADVL_fcl',
#  "CJT_v-ger -_> 'vendendo'",
#  "H_adj -_> 'multinacional'",
#  '-P_vp -_> MV_v-inf',
#  "SUBJ_num -_> '61,22m'",
#  'P_icl -_> PIV_pp',
#  '-N_<_ap -_> KOMP_<_acl',
#  'ADVL_advp -_> AS_<_n',
#  "A_<_adv -_> 'aproximadamente'",
#  'ADVL/PIV_pp -_> P_<_np',
#  "ADVL_adj -_> 'forte'",
#  "H_v-inf -_> 'trajar'",
#  '-- -_> .',
#  'OC_icl -_> ADVL_pp',
#  'CJT&ACC_fcl -_> ACC_prop',
#  'SC_advp -_> KOMP_<_acl',
#  'ACC_cu- -_> CJT_np',
#  "ADVL_v-pcp -_> 'refrescado'",
#  "H_v-fin -_> 'fazia'",
#  "_>S_adv -_> 'sobretudo'",
#  "P_<_v-inf -_> 'colaborar'",
#  '« -_> ?_cu',
#  '-_>N_pp -_> -P_<_np',
#  'P_<_acl -_> ADVS_pp',
#  "SUB_adv -_> 'que'",
#  '-ADVL_pp- -_> -P_<_icl-',
#  'PIV/N_<[-3]_pp -_> P_<_icl',
#  'APP_cu -_> CJT_np',
#  'ADVL/ADVL[-3]_advp -_> A_<_pp',
#  '-ACC_fcl -_> P_vp',
#  "ADVL_pron-indp -_> 'que'",
#  "ACC_v-pcp -_> 'errado'",
#  'N_</N_<[_2]_pp -_> ADVL_pp',
#  'P_<_cu -_> CJT_n',
#  '-OC_icl -_> PIV_pp',
#  'ADVL/N_<[_2]_pp -_> P_<_cu',
#  'N_</N_<[-2]_pp -_> P_<_np',
#  'UTT_cu -_> .',
#  'P_cu- -_> CO_conj-c',
#  "_>N_ec -_> 'anti-'",
#  'N_<PRED_cu -_> CJT_acl',
#  'SC_ap- -_> H_adj',
#  '_>N_cu -_> CJT_num',
#  '-ADVL_advp -_> KOMP_<_icl',
#  'ADVL_advp- -_> A_<_pp-',
#  'ADVL/ADVL[-1]_icl -_> ACC_np',
#  "CJT_pron-pers -_> 'Eu'",
#  "_>N_pron-det -_> 'tanta'",
#  "CJT_adv -_> 'a_posteriori'",
#  "ADVS_adj -_> 'vencedora'",
#  'A_<_pp -_> »',
#  'SC_cu -_> CJT_adj',
#  "ADVO_adv -_> 'mal'",
#  "SC_num -_> 'nove'",
#  'N_<PRED/N_<PRED[_7]_fcl -_> SC_np',
#  'N_<_pp- -_> P_<_icl-',
#  'ADVL/A_<[_1]_pp -_> P_<_np',
#  "PAUX_v-ger -_> 'tendo'",
#  'NUM_<_pp -_> P_<_num',
#  "PRED_pron-det -_> 'todos'",
#  '_>N_icl -_> P_v-pcp',
#  '-MV_cu -_> CJT_v-pcp',
#  'CJT&?_? -_> -P_vp',
#  'CJT_vp -_> MV_v-inf',
#  "* -_> '*'",
#  '-SUBJ_ap -_> A_<_fcl',
#  "CJT_adj -_> 'urbana'",
#  '_>N_acl -_> SUBJ_pron-det',
#  "N_<PRED_v-pcp -_> 'realizado'",
#  "CJT_in -_> 'não'",
#  "SC_pron-pers -_> 'você'",
#  'P_<_pp -_> P_<_cu',
#  "_>A_adj -_> 'demasiado'",
#  'PRED_fcl -_> ACC_cu',
#  'N_<_ap- -_> H_adj',
#  "ACC_prop -_> 'Maastricht'",
#  "SUBJ_pron-pers -_> 'você'",
#  "P_v-ger -_> 'respondendo'",
#  'ADVL/PRED_icl -_> ACC_np',
#  "ACC_pron-det -_> 'outra'",
#  'ACC_advp- -_> H_adv',
#  "VOC_pron-pers -_> 'se'",
#  'A_<PRED_ap -_> A_<_pp',
#  '-N_<_fcl -_> -PIV_pp',
#  "A_<_adj -_> 'possível'",
#  '-ACC_cu -_> CJT_np',
#  'APP_np -_> N_<_fcl',
#  "ADVS_adv -_> 'perto'",
#  'CJT_pp- -_> _>P_adv',
#  'H_advp -_> A_<_adv',
#  'UTT_ap -_> .',
#  "{ -_> '{'",
#  "CO_conj-s -_> 'e'",
#  'STA_fcl -_> .',
#  '-ADVL_pp -_> -P_<_icl',
#  '-CJT_fcl -_> -?_cu',
#  "H_pron-det -_> 'própria'",
#  'PCJT_pp -_> P_<_adv',
#  'SC_np- -_> N_<_cu-',
#  '-P_cu -_> ?_icl',
#  'ADVL_ap -_> A_<_np',
#  'PMV_cu -_> MV_v-inf',
#  'UTT_pp -_> .',
#  "CJT_pron-det -_> 'várias'",
#  '-P_<_icl -_> ACC_np',
#  'SC_vp -_> P_<_v-inf',
#  'SUBJ_ap -_> H_num',
#  "P_<_pron-indp -_> 'tudo_isso'",
#  "PRT-AUX_<_prp -_> 'para'",
#  'N_<PRED/N_<PRED[-2]_fcl -_> OC_adj',
#  "ACC_adv -_> 'como'",
#  "FOC_conj-s -_> 'que'",
#  '»" -_> \'que\'',
#  "PIV_pron-det -_> 'a'",
#  "H_num -_> 'nove'",
#  'CJT_cu -_> CJT_fcl',
#  "CJT_prp -_> 'para'",
#  "A_<_prop -_> 'FTP'",
#  "? -_> '?'",
#  "TOP_pron-det -_> 'esse'",
#  '?_cu -_> CJT_acl',
#  'ADVL/N_<[_1]_pp -_> P_<_cu',
#  "H_v-pcp -_> 'perturbado'",
#  'ADVS_icl -_> ADVL_pp',
#  '?_cu- -_> CJT_pp',
#  "N_<PRED_prop -_> 'Luis_Inácio_Lula_da_Silva'",
#  'AS_<_np -_> N_<_pp',
#  'N_<PRED_advp -_> A_<_pp',
#  'H_acl -_> SC_np',
#  'STA_np -_> .',
#  'SUB_advp -_> H_conj-s',
#  'N_<_? -_> ?_pp',
#  'MV_cu -_> CJT_v-pcp',
#  '.. -_> CJT_v-pcp',
#  "?_pron-pers -_> 'a'",
#  'PMV_vp- -_> PRT-AUX_<_prp',
#  'N_<_icl- -_> ADVL_pp',
#  "P_<_v-fin -_> 'entender'",
#  'ADVL_icl- -_> ACC_pron-pers',
#  '-APP_cu -_> ,',
#  "P_n -_> 'vistos'",
#  'P_<_icl -_> ADVL_pp',
#  '_>A_advp -_> _>A_adv',
#  "ADVS_pp -_> 'em_casa'",
#  'SC_icl- -_> ADVL_pp',
#  'PAUX_cu -_> CJT&ADVL_adv',
#  'P_<_advp -_> A_<_pp',
#  'OC_acl -_> SC_cu',
#  "' -_> '''",
#  'N_<PRED_icl -_> ADVL_pp',
#  'PRED_pp -_> P_<_ap',
#  "P_v-pcp -_> 'incorporada'",
#  'EXC_icl -_> !',
#  'PRED_cu -_> CJT_pp',
#  "CO_conj-c -_> 'ou'",
#  "CJT_v-inf -_> 'fazer'",
#  "?_adv -_> 'principalmente'",
#  "PIV_prp -_> 'a'",
#  "APP_n -_> 'revolução'",
#  '-ACC_advp -_> KOMP_<_acl',
#  'ACC_fcl- -_> SUB_conj-s',
#  "AUX_v-ger -_> 'voltando'",
#  'P_<_cu- -_> CO_conj-c',
#  "_>N/ADVL[-1]_adv -_> 'ainda'",
#  '" -_> \'"\'',
#  "N_</ADVL[-3]_adv -_> 'hoje'",
#  'KOMP_<_pp -_> P_<_adv',
#  "AUX_v-pcp -_> 'acabado'",
#  'ADVL_np- -_> H_pron-indp',
#  "VOK_n -_> 'governador'",
#  "N_<PRED_adj -_> 'governista'",
#  'N_<PRED/UTT[-4]_np -_> N_<_pp',
#  'N_</N_<[_1]_pp -_> P_<_np',
#  'ADVS_cu -_> ,',
#  "?_? -_> 'que'",
#  'N_<PRED_fcl- -_> ADVL_pp-',
#  "VOC_n -_> 'filho'",
#  'A_<_fcl -_> S_<_fcl',
#  "_>A_n -_> 'passado'",
#  'SC_icl -_> SC_np',
#  '_>A_advp- -_> H_adv',
#  'A_<_icl -_> ADVL_pp',
#  "ACC_in -_> 'basta'",
#  "H_n -_> 'inocência'",
#  'N_</N_<[_2]_fcl -_> ACC_np',
#  'N_<PRED/N_<PRED[_2]_fcl -_> ADVL/N_<[_1]_pp',
#  'N_</ADVL[-1]_cu -_> CJT_pp',
#  "_>N_prop -_> 'Santa_Casa_da_Misericórdia'",
#  'PASS_cu -_> CJT_pp',
#  'STA_icl -_> P_v-inf',
#  '_>N_ap- -_> H_num',
#  '-H_cu -_> CJT_pp',
#  "H_pron-pers -_> 'elas'",
#  "N_<_num_11-5353' -_> '{0800}_11-5353'",
#  "COM_adv -_> 'Como'",
#  "N_<_pron-det -_> 'mesmos'",
#  "ACC_QUE -_> '",
#  "OC_pp -_> 'em_pé_de_igualdade'",
#  "PRED_adj -_> 'emotiva'",
#  'EXC_fcl -_> !',
#  'ADVS_advp -_> A_<_pp',
#  '... -_> A_<_pp',
#  "_>N_adj -_> 'bonitos'",
#  'EXC_cu -_> !',
#  'CJT_?- -_> ADVL_pp',
#  "N_<_num_877-8740' -_> '{011}_887-8740'",
#  'MV_cu- -_> CO_conj-c',
#  'P_<_fcl -_> ADVL_icl',
#  '-ADVS_advp -_> A_<_pp',
#  "SC_pp -_> 'de_rastos'",
#  "ADVL_num' -_> '4}'",
#  "OC_adj -_> 'visível'",
#  "ADV_adv -_> 'Porquê'",
#  'ADVL_ap- -_> H_adv',
#  'OC_icl- -_> P_v-pcp',
#  "P_v-inf -_> 'aturar'",
#  '-N_<PRED_cu -_> CJT_icl',
#  "ACC_adj -_> 'velho'",
#  "ADVL_prop -_> 'Brasília'",
#  '-PIV_cu -_> -CJT_pp',
#  'CJT_pp -_> P_<_np',
#  "P_<_in -_> 'já'",
#  'AS_<_pp -_> P_<_np',
#  "N_<_v-pcp -_> 'derrotado'",
#  "UTT_prop -_> 'Broz'",
#  "N_<PRED_num_661-2458' -_> '{034}_661-2458'",
#  'SUBJ_np -_> APP_np',
#  "H_prop' -_> 'Decreto_regulamentar_19/19_{B}'",
#  "SUBJ_adj -_> 'Nacionais-comunistas'",
#  'N_<_np -_> N_<_num',
#  'ADVL/N_<[_3]_pp -_> P_<_num',
#  'N_<_vp -_> MV_v-inf',
#  '_>A_pp -_> P_<_adv',
#  'N_<PRED_np -_> N_<PRED_icl',
#  '-SC_np -_> H_n',
#  'KOMP_<_icl -_> SC_icl',
#  "PMV_v-fin -_> 'desencadear'",
#  'ACC_fcl -_> ACC_acl',
#  'ADVL_acl -_> SUBJ_v-pcp',
#  '-SC_pp -_> -P_<_np',
#  "APP_num -_> '1937'",
#  "ACC_v-inf -_> 'fazer'",
#  '-CJT_? -_> ACC_icl',
#  "N_<_num -_> '7,00'",
#  "} -_> '}'",
#  '-SC_cu -_> ,',
#  "SUBJ_pron-det -_> 'Ambos'",
#  "P_adv -_> 'recém-galardoado'",
#  "UTT_n -_> 'Resposta'",
#  '-H_icl -_> -ACC_np',
#  "- -_> '-'",
#  'PRED_icl -_> PASS_pp',
#  'UTT_np -_> ;',
#  'STA_cu -_> CJT_acl',
#  'A_<_vp -_> P_<_v-inf',
#  'CJT&ACC_np -_> N_<_pron-indp',
#  "MV_v-fin -_> 'visita-'",
#  'SUBJ_icl- -_> ACC_fcl-',
#  "CJT&AUX_v-fin -_> 'deve'",
#  'CO_icl -_> ADVL_adv',
#  '-SC_ap -_> KOMP_<_icl',
#  "H_conj-s -_> 'porque'",
#  'A_<_acl -_> ADVL_pp',
#  'SUB_pp -_> P_<_pron-indp',
#  '_>N_fcl -_> ACC_adv',
#  'CJT_icl -_> ADVL_pp',
#  "! -_> '!'",
#  "P_<_v-pcp -_> 'derrotado'",
#  '_>A_fcl -_> P_v-fin',
#  'ADVL_pp- -_> P_<_np-',
#  "UTT_v-pcp -_> 'Recomendados'",
#  'VOC_np -_> N_<_prop',
#  'ACC_cu -_> H_cu',
#  "SC_n -_> 'beneficiário'",
#  "OC_adv -_> 'claro'",
#  'N_<_icl -_> »',
#  "CJT_pron-indp -_> 'ninguém'",
#  'H_cu- -_> ,',
#  'S_<_cu -_> CJT_fcl',
#  'KOMP_<_cu -_> CJT_pp',
#  '-PASS_np -_> -P_<_np',
#  "SC_pron-det -_> 'poucas'",
#  "APP_prop -_> 'Luiz_Henrique_Barros_de_Arruda'",
#  "ACC_n -_> 'divertimento'",
#  'P_<_ap -_> APP_np',
#  'N_<PRED_pp -_> P_<_np',
#  "PAUX_v-inf -_> 'ter'",
#  'SC_acl -_> SC_cu',
#  'PIV_pp- -_> P_<_np-',
#  'AUX_<_cu -_> CJT_icl',
#  'P_vp -_> MV_v-ger',
#  'SUBJ_ap- -_> A_<_pp',
#  "FOC_v-fin -_> 'era'",
#  '-SUBJ_icl- -_> P_v-inf',
#  'PIV_np- -_> P_<_np-',
#  'SUBJ_advp -_> KOMP_<_pp',
#  '-ADVL_ap -_> KOMP_<_acl',
#  "ADVS_n -_> 'ouro'",
#  "PCJT_num -_> '1.85000'",
#  "SUBJ_conj-s -_> 'A_não_ser_que'",
#  "P_<_pron-det -_> 'outra'",
#  "ADVL_adv -_> 'por_outro_lado'",
#  'ADVO_pp -_> P_<_pp',
#  'N_<PRED_fcl -_> AUX_<_?',
#  "CJT_v-pcp -_> 'desconhecido'",
#  "_>N_n -_> 'forte'",
#  "ADVL_num -_> '4-1'",
#  '-PIV_pp -_> -P_<_icl',
#  '-SUBJ_np- -_> N_<_fcl',
#  "N_<PRED_prop' -_> 'Salazar_e_Caetano_--_Cartas_Secretas_{1932-1968}'",
#  'STA_vp -_> .',
#  "SUB_conj-s -_> 'por'",
#  'N_</ADVL[-3]_pp -_> P_<_prop',
#  "_>A_art -_> 'os'",
#  '_>A_ap- -_> H_adv',
#  'H_? -_> A_<_pp',
#  '-PRED_cu -_> CJT_icl',
#  "[ -_> '['",
#  "CJT&ADVL_adv -_> 'vice-versa'",
#  "] -_> ']'",
#  '-H_np -_> N_<PRED_pp',
#  "A_<_pron-indp -_> 'isso'",
#  'ACC_pp -_> H_prop',
#  'COM_icl -_> »',
#  'ADVL/N_<[-1]_pp -_> P_<_icl',
#  'MV_ap -_> H_v-pcp',
#  'ADVS_advp- -_> _>A_advp',
#  "SC_prop -_> 'AJ'",
#  'SUBJ_cu- -_> H_cu',
#  "_>N_pron-indp -_> 'tudo'",
#  "?_n -_> 'vide'",
#  "N_<PRED_n -_> 'estupefação'",
#  "H_prop -_> 'Álvaro_Martins'",
#  'ADVS_? -_> ?_pp']

# %%
rules = nltk.CFG.fromstring(" \n ".join(CFG))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.virtualenvs/pln/lib/python3.5/site-packages/nltk/grammar.py in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1455                 # expand out the disjunctions on the RHS
# -> 1456                 productions += _read_production(line, nonterm_parser, probabilistic)
#    1457         except ValueError as e:
#
# ~/.virtualenvs/pln/lib/python3.5/site-packages/nltk/grammar.py in _read_production(line, nonterm_parser, probabilistic)
#    1359     if not m:
# -> 1360         raise ValueError('Expected an arrow')
#    1361     pos = m.end()
#
# ValueError: Expected an arrow
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7fd234fb5804> in <module>
# ----> 1 rules = nltk.CFG.fromstring(" \n ".join(CFG))
#
# ~/.virtualenvs/pln/lib/python3.5/site-packages/nltk/grammar.py in fromstring(cls, input, encoding)
#     564         """
#     565         start, productions = read_grammar(
# --> 566             input, standard_nonterm_parser, encoding=encoding
#     567         )
#     568         return cls(start, productions)
#
# ~/.virtualenvs/pln/lib/python3.5/site-packages/nltk/grammar.py in read_grammar(input, nonterm_parser, probabilistic, encoding)
#    1456                 productions += _read_production(line, nonterm_parser, probabilistic)
#    1457         except ValueError as e:
# -> 1458             raise ValueError('Unable to parse line %s: %s\n%s' % (linenum + 1, line, e))
#    1459
#    1460     if not productions:
#
# ValueError: Unable to parse line 2: P<_? -> ?_pp
# Expected an arrow

# %% [markdown]
# # Parsers
#
# ## ChartParser
#
# - Is slow and not memory efficient.
# - Can handle left-recursive grammars.
# - Always finds all possible syntax trees.
# - Is the best parser to start with. Consider other parsers only if this one is not fast enough or it’s not memory efficient enough.
#
# ## RecursiveDescentParser¶
#
# - Does top-down parsing.
# - Does not work with left-recursive productions (they sent it to an infinite loop).
# - Wastes a lot of time, considering words and structures that do not correspond to the input sentence.
# - When backtracking, this parser discards parsed constituents that will need to be rebuilt again later.
#
# ## ShiftReduceParser¶
#
# - Does bottom-up parsing.
# - Does not implement any backtracking, so it is not guaranteed to find a parse for a text, even if one exists. - Furthermore, it will only find at most one parse, even if more parses exist.

# %%
parser =  nltk.parse.BottomUpChartParser(rules)

sentence = 'Eu mordi um elefante com meus pijamas'.lower().split()
trees = parser.parse(sentence)
for tree in trees:
    print(tree)

# %% [markdown]
# # Extending the lexicon
# - use http://nilc.icmc.usp.br/embeddings

# %%
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format('skip_s50.txt')

# %%
sentence = 'Eu mordi um elefante com minhas calças'.lower().split()
parser = nltk.ChartParser(simple_grammar)
trees = parser.parse(sentence)
for tree in trees:
    try:
        print(tree)
    except e:
        print(e)
